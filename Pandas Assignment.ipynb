# %% [markdown]
# Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df=pd.read_csv("../data engineering practice/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
# my logic
# which is wrong
for i in range(len(df)):
    if df['HP'][i]>=200:
        print(df.iloc[i])
# Out:
# #                 113
# Name          Chansey
# Type 1         Normal
# Type 2            NaN
# HP                250
# hamla               5
# bachaw              5
# Sp. Atk            35
# Sp. Def           105
# Speed              50
# Generation          1
# Legendary       False
# Name: 121, dtype: object
# #                 242
# Name          Blissey
# Type 1         Normal
# Type 2            NaN
# HP                255
# hamla              10
# bachaw             10
# Sp. Atk            75
# Sp. Def           135
# Speed              55
# Generation          2
# Legendary       False
# Name: 261, dtype: object

# %%
# 1st method
# basic method
df[df['HP']>=190]
# Out:
#        #       Name   Type 1 Type 2   HP  hamla  bachaw  Sp. Atk  Sp. Def  \
# 121  113    Chansey   Normal    NaN  250      5       5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190     33      58       33       58
# 261  242    Blissey   Normal    NaN  255     10      10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 217     33           2      False
# 261     55           2      False

# %%
# 2nd method
# using isin method

options = ['Fire', 'Rock']
ans= df[df['Type 1'].isin(options)]
ans
# Out:
#        #                       Name Type 1  Type 2   HP  hamla  bachaw  \
# 4      4                 Charmander   Fire     NaN   39     52      43
# 5      5                 Charmeleon   Fire     NaN   58     64      58
# 6      6                  Charizard   Fire  Flying   78     84      78
# 7      6  CharizardMega Charizard X   Fire  Dragon   78    130     111
# 8      6  CharizardMega Charizard Y   Fire  Flying   78    104      78
# ..   ...                        ...    ...     ...  ...    ...     ...
# 769  699                    Aurorus   Rock     Ice  123     77      72
# 773  703                    Carbink   Rock   Fairy   50     50     150
# 795  719                    Diancie   Rock   Fairy   50    100     150
# 796  719        DiancieMega Diancie   Rock   Fairy   50    160     110
# 799  721                  Volcanion   Fire   Water   80    110     120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         60       50     65           1      False
# ...

# %%
# combin both 1st and 2nd method
options2 = ['Fire', 'Rock']
  

ans2 = df[(df['HP']>100) & (df['Type 1'].isin(options2))]
ans2
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 263  244                    Entei   Fire       NaN  115     115       85
# 270  250                    Ho-oh   Fire    Flying  106     130       90
# 559  500                   Emboar   Fire  Fighting  110     123       65
# 615  555  DarmanitanStandard Mode   Fire       NaN  105     140       55
# 616  555       DarmanitanZen Mode   Fire   Psychic  105      30      105
# 769  699                  Aurorus   Rock       Ice  123      77       72
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 263       90       75    100           2       True
# 270      110      154     90           2       True
# 559      100       65     65           5      False
# 615       30       55     95           5      False
# 616      140      105     55           5      False
# 769       99       92     58           6      False

# %% [markdown]
# Q4. How do you rename columns in a Pandas DataFrame?

# %%
df.rename(columns = {'Attack':'hamla','Defense':'bachaw'}, inplace = True)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  hamla  bachaw  Sp. Atk  \
# 0      1              Bulbasaur    Grass  Poison  45     49      49       65
# 1      2                Ivysaur    Grass  Poison  60     62      63       80
# 2      3               Venusaur    Grass  Poison  80     82      83      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80    100     123      122
# 4      4             Charmander     Fire     NaN  39     52      43       60
# ..   ...                    ...      ...     ...  ..    ...     ...      ...
# 795  719                Diancie     Rock   Fairy  50    100     150      100
# 796  719    DiancieMega Diancie     Rock   Fairy  50    160     110      160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80    110      60      150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80    160      60      170
# 799  721              Volcanion     Fire   Water  80    110     120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Q5. How do you drop columns in a Pandas DataFrame?

# %%
df.drop('Legendary',axis=1)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 0         65       65     45           1
# 1         80       80     60           1
# ...

# %% [markdown]
# Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
print(df['Type 1'].unique())



# number of unique values
df['Type 1'].nunique()
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
# 18

# %% [markdown]
# Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df2.fillna("@@@@@@@@@")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male       22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38.0
# 2                               Heikkinen, Miss. Laina  female       26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0
# 4                             Allen, Mr. William Henry    male       35.0
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# Q9. How do you concatenate two Pandas DataFrames?

# %%
data2={'Name':['amy','aki','sivi','ganu'],
      'age':[11,21,31,41]}
data3={'Name':['ram','lakhan','raju'],
      'age':[64,78,38]}

a=(len(data2['Name']))
b=(len(data3['Name']))

d2=pd.DataFrame(data2)
d3=pd.DataFrame(data3,index=range(a,a+b))


d=[d2,d3]
pd.concat(d,axis=0)
# Out:
#      Name  age
# 0     amy   11
# 1     aki   21
# 2    sivi   31
# 3    ganu   41
# 4     ram   64
# 5  lakhan   78
# 6    raju   38

# %% [markdown]
# Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df11 = pd.DataFrame({'Name':['Raju', 'Rani', 'Geeta', 'Sita', 'Sohit'],
                    'Marks':[80, 90, 75, 80, 80]})
  

df12 = pd.DataFrame({'Name':['Raju', 'Divya', 'Geeta', 'Sita'],
                    'Grade':['A', 'A', 'B', 'A'],
                    'Rank':[3, 1, 4, 2 ],
                    'Gender':['Male', 'Female', 'Female', 'Female']})
print(df11)
print()
print(df12)
# first merge

df11.merge(df12[['Name','Grade','Rank']],on='Name')
# Out:
#     Name  Marks
# 0   Raju     80
# 1   Rani     90
# 2  Geeta     75
# 3   Sita     80
# 4  Sohit     80
#
#     Name Grade  Rank  Gender
# 0   Raju     A     3    Male
# 1  Divya     A     1  Female
# 2  Geeta     B     4  Female
# 3   Sita     A     2  Female
#     Name  Marks Grade  Rank
# 0   Raju     80     A     3
# 1  Geeta     75     B     4
# 2   Sita     80     A     2

# %%
# second merge
df11.merge(df12[['Name','Grade','Rank']],on='Name',how='left')
# Out:
#     Name  Marks Grade  Rank
# 0   Raju     80     A   3.0
# 1   Rani     90   NaN   NaN
# 2  Geeta     75     B   4.0
# 3   Sita     80     A   2.0
# 4  Sohit     80   NaN   NaN

# %%
# third merge
df11.merge(df12[['Name','Grade','Rank']],on='Name',how='right')
# Out:
#     Name  Marks Grade  Rank
# 0   Raju   80.0     A     3
# 1  Divya    NaN     A     1
# 2  Geeta   75.0     B     4
# 3   Sita   88.0     A     2

# %% [markdown]
# Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
df.groupby('Type 1').aggregate(['max','min'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_20192\1748868303.py:1: FutureWarning: ['Type 2'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Type 1').aggregate(['max','min'])
#             #                        Name                         HP      \
#           max  min                    max                   min  max min
# Type 1
# Bug       666   10                Yanmega              Accelgor   86   1
# Dark      717  197               Zweilous                 Absol  126  35
# Dragon    718  147       Zygarde50% Forme               Altaria  125  41
# Electric  702   25              Zebstrika              Ampharos   90  20
# Fairy     716   35                Xerneas            Aromatisse  126  35
# Fighting  701   56                Tyrogue            Conkeldurr  144  30
# Fire      721    4                 Vulpix              Arcanine  115  38
# ...

# %%
df.groupby('Type 1').aggregate({'HP':['max','min'],'Name':['count']})
# Out:
#            HP      Name
#           max min count
# Type 1
# Bug        86   1    69
# Dark      126  35    31
# Dragon    125  41    32
# Electric   90  20    44
# Fairy     126  35    17
# Fighting  144  30    27
# Fire      115  38    52
# Flying     85  40     4
# Ghost     150  20    32
# Grass     123  30    70
# Ground    115  10    32
# Ice       110  36    24
# Normal    255  30    98
# Poison    105  35    28
# Psychic   190  20    57
# Rock      123  30    44
# Steel     100  40    27
# Water     170  20   112

# %% [markdown]
# Q12. How do you pivot a Pandas DataFrame?

# %%
# The pivot() function is used to reshaped a given DataFrame organized by given index / column values.

df14 = pd.DataFrame({'fff': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bbb': ['P', 'Q', 'R', 'P', 'Q', 'R'],
                   'baa': [2, 3, 4, 5, 6, 7],
                   'zzz': ['h', 'i', 'j', 'k', 'l', 'm']})
df14
# Out:
#    fff bbb  baa zzz
# 0  one   P    2   h
# 1  one   Q    3   i
# 2  one   R    4   j
# 3  two   P    5   k
# 4  two   Q    6   l
# 5  two   R    7   m

# %%
df14.pivot(index='fff', columns='bbb', values='baa')
# Out:
# bbb  P  Q  R
# fff
# one  2  3  4
# two  5  6  7

# %% [markdown]
# Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
# before data type conversion
print(df11.dtypes)

# after data type conversion
a={'Marks':str}
p=df11.astype(a)
print(p.dtypes)
# Out:
# Name     object
# Marks     int64
# dtype: object
# Name     object
# Marks    object
# dtype: object

# %% [markdown]
# Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
df11.sort_values(by=['Marks','Name'],ascending=[False,True])
# Out:
#     Name  Marks
# 1   Rani     90
# 0   Raju     80
# 3   Sita     80
# 4  Sohit     80
# 2  Geeta     75

# %% [markdown]
# Q15. How do you create a copy of a Pandas DataFrame?

# %%
# The copy() method returns a copy of the DataFrame.

# By default, the copy is a "deep copy" meaning that any changes made in the original DataFrame will NOT be 
# reflected in the copy.

# Note: With the parameter deep=False, it is only the reference to the data (and index) that will be copied, 
# and any changes made in the original will be reflected in the copy, and, any changes made in the copy
# will be reflected in the original.
newdf=df.copy()
newdf
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                           
                          'Age': [30, 35, 37, 33, 34, 30],
                           
                          'Salary': [100000, 93000, 88000, 120000, 940000, 95000],
                           
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})

# normal way by using and operator
display(dataFrame[(dataFrame['Salary']>=100000)& (dataFrame['Age']< 40)& (dataFrame['JOB'].str.startswith('D'))][['Name','JOB']])


# in sql manner
display(dataFrame.query('Salary  <= 100000 & Age < 40 & JOB.str.startswith("C").values'))
# Out:
#         Name       JOB
# 0   RACHEL    DESIGNER
#         Name  Age  Salary   JOB
# 1   MONICA     35   93000  CHEF

# %%
Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
# first way
print(newdf.aggregate({'Attack':['mean']}))
# second way
newdf['Attack'].mean(skipna=False)

# skipna= false means skip value also calculated in calculation
# Out:
#         Attack
# mean  79.00125
# 79.00125

# %%
Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
# first way
print(newdf.aggregate({'Attack':['std']}))
# second way
newdf['Attack'].std()
# Out:
#         Attack
# std  32.457366
# 32.45736586949845

# %%
Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
newdf['Attack'].corr(newdf['HP'])
# Out:
# 0.422386028776223

# %%
Q20. How do you select specific columns in a DataFrame using their labels?

# %%
newdf['Attack']
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 4       52
#       ...
# 795    100
# 796    160
# 797    110
# 798    160
# 799    110
# Name: Attack, Length: 800, dtype: int64

# %% [markdown]
# Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
display(newdf.iloc[0])
newdf.loc[0]
# Out:
# #                               384
# Name          RayquazaMega Rayquaza
# Type 1                       Dragon
# Type 2                       Flying
# HP                              105
# Attack                          180
# Defense                         100
# Sp. Atk                         180
# Sp. Def                         100
# Speed                           115
# Generation                        3
# Legendary                      True
# Total                           780
# Name: 426, dtype: object
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Total               318
# Name: 0, dtype: object

# %% [markdown]
# Q22. How do you sort a DataFrame by a specific column?

# %%
newdf.sort_values(by=['Total'],ascending=False)

# %% [markdown]
# Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
newdf['Total']=newdf['HP']+newdf['Attack']+newdf['Defense']+newdf['Sp. Atk']+newdf['Sp. Def']+newdf['Speed']
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# ..   ...                    ...      ...       ...  ...     ...      ...
# 13    10               Caterpie      Bug       NaN   45      30       35
# 288  265                Wurmple      Bug       NaN   45      45       35
# 446  401              Kricketot      Bug       NaN   37      25       41
# 322  298                Azurill   Normal     Fairy   50      20       40
# 206  191                Sunkern    Grass       NaN   30      30       30
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %% [markdown]
# Q24. How do you remove duplicates from a DataFrame?

# %%
# check for all rows all values
display(newdf.drop_duplicates())
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# =>subset: Subset takes a column or list of column label. It’s default value is none. After passing columns,
#     it will consider them only for duplicates. 
# =>keep: keep is to control how to consider duplicate value. It has only three distinct value and default
#       is ‘first’. 
#       If ‘first‘, it considers first value as unique and rest of the same values as duplicate.
#       If ‘last‘, it considers last value as unique and rest of the same values as duplicate.
#       If False, it consider all of the same values as duplicates
# =>inplace: Boolean values, removes rows with duplicates if True.

display(newdf.drop_duplicates(subset="Type 1",keep='first', inplace=True))
newdf
# Out:
# None
#        #                     Name    Type 1   Type 2  HP  Attack  Defense  \
# 0      1                Bulbasaur     Grass   Poison  45      49       49
# 4      4               Charmander      Fire      NaN  39      52       43
# 9      7                 Squirtle     Water      NaN  44      48       65
# 13    10                 Caterpie       Bug      NaN  45      30       35
# 20    16                   Pidgey    Normal   Flying  40      45       40
# 28    23                    Ekans    Poison      NaN  35      60       44
# 30    25                  Pikachu  Electric      NaN  35      55       40
# 32    27                Sandshrew    Ground      NaN  50      75       85
# 40    35                 Clefairy     Fairy      NaN  70      45       48
# 61    56                   Mankey  Fighting      NaN  40      80       35
# 68    63                     Abra   Psychic      NaN  25      20       15
# 80    74                  Geodude      Rock   Ground  40      80      100
# ...

# %% [markdown]
# Q25. What is the difference between .loc and .iloc in Pandas?

# %%
# solution:
#     .loc is used for normal indexing
# where .iloc is used for system generate index
